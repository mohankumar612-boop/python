# %%
#1.Find the error in the following Python code:
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#Caps M changed to lower case m

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

# %%
#Error Expected 1 input Argument (x) in the funciton and should declared global

# %%
#3.x = 5
if x = 10:
    print("x is 10")

# %%
#Error: Syntax Error and x is not called in print, == required

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

# %%
#Error: get it sorted first and pass numbers in print as numbers.sort()

# %%
#5.
def square(n):
    a= n * n

print(a)

# %%
#Error: variable not assigned to the operand
square(4)

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

# %%
#Error: 2 will be replaced as 5 in 1st index
my_tuple = [1, 2, 3]
my_tuple[1] = 5
print (my_tuple)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# %%
#Error: not formatted and to pass parameter in curly brasis
print(f"My name is {name} and I am {age} years old")

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#No Error

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
#Error: swap the position from 5 to 1 and 1 to 5.
for i in range(1,5):
    print (i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])

# %%
#Error: print with formatter name and age
student={"name":"john","age":20}
print(f"student {name} {age}")
# Out:
# student Alice 25
