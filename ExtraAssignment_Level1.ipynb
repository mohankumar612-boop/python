# %%
#print Statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy Inputs
EnterInsName=input("Enter your institute name? :")
# Out:
# Enter your institute name? : HOPE AI

# %%
#Addition
num1=43
num2=34
add=num1+num2
print("add =",add)
# Out:
# add = 77

# %%
#Subtraction
num1=43
num2=34
sub=num1-num2
print("Sub =",sub)
# Out:
# Sub = 9

# %%
#Multiplication
num1=63
num2=97
mul=num1*num2
print("Mul =",mul)
# Out:
# Mul = 6111

# %%
#Division
num1=76
num2=31
div=num1/num2
print("Float DIV =",div)
# Out:
# Float DIV = 2.4516129032258065

# %%
#Floor Division
num1=76
num2=31
fdiv=num1//num2
print("Floor DIV =",fdiv)
# Out:
# Floor DIV = 2

# %%
#Modulo
num1=76
num2=31
mod=num1%num2
print("Modulo =",mod)
# Out:
# Modulo = 14

# %%
#Power
num1=4
num2=4
result1=num1**num2
print("Power =",result1)
# Out:
# Power = 256
