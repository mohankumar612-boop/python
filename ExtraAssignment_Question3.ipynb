# %%
#Assignment Operator
i=int(input("Value:"))
if (i==10):
    print("CORRECT")
else: print("InCorrect")
# Out:
# Value: 10
# CORRECT

# %%
## Check the password, using if and else
EnPass=input("Enter the Password:")
if(EnPass=="HOPE@123"):print("Your Password is Correct")
else: print("Your Password is Wrong")
# Out:
# Enter the Password: HOPE@123
# Your Password is Correct

# %%
# Catagory the people by their age like children, adult, citizen, senior citizen...
findage=int(input("age: "))
if(findage>=20):print("Adult") 
else: print("Child")
# Out:
# age:  20
# Adult

# %%
# Find whether given number is positive or negative
eno=int(input("Enter any number:"))
if (eno>0):print("NO. is Positive")
else: print("NO. is Negative")
# Out:
# Enter any number: 1
# NO. is Positive

# %%
# Check whether the given number is divisible by 5
eno=int(input("Enter a number to Check:"))
if (eno%5==0):print("NO. is divisible by 5")
else: print("NO. is not divisible by 5")
# Out:
# Enter a number to Check: 52
# NO. is not divisible by 5
