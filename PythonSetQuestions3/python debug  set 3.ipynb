# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name):
    print("Hello, ", name)

# %%
#colon is missing and comma is missing
say_hello('Mohan')

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + age + " years old")

# %%
#Print Statement is Error
age = 25
print(f"I am {age} age years old")

# %%
#3.Question:
What is the issue with the following code?

def greet():
    message = "Hello"
print(message)

# %%
#

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5,2))
# Out:
# 7

# %%
#Missing 1 Parameter in print
print(add(5,2))

# %%
#5.What is wrong with this code?

def is_even(n):
    if ((n % 2) == 1):
        return True
    else:
        return False

# %%
#Call the method
is_even(5)

# %%
#6.What happens when you run this code?

num = int("10a")
print(num)

# %%
#instead of int it has string value. To change to int value.
num=int(10)
print(num)
# Out:
# 10

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort()
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#sorted and reversed
#numbers.sort()
#numbers.reverse()

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#It will append 4
#numbers.append(4)

# %%
#9.What will happen when you run the following code?
    
global count=int(10)
def increment():
    if(count==10):
        count += 1
    return count
        print(count)

#increment()

# %%
#declare count as global variable
increment()

# %%
#10.What error will occur in the following code?

text = "Python"
print(text[10])

# %%
#index out of range
